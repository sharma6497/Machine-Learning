# %% [markdown]
# ### ATTRIBUTES:

# %% [markdown]
# 1. country = Name of the country
# 2. child_mort = Death of children under 5 years of age per 1000 live births
# 3. exports = Exports of goods and services. Given as %age of the Total GDP
#
# 4. health = Total health spending as %age of Total GDP
#
# 5. imports =  Imports of goods and services. Given as %age of the Total GDP
#
# 6. Income =  Net income per person
#
# 7. Inflation =  The measurement of the annual growth rate of the Total GDP
#
# 8. life_expec = The average number of years a new born child would live if the current mortality patterns are to remain the same
#
# 9. total_fer = The number of children that would be born to each woman if the current age-fertility rates remain the same.
#
# 10. gdpp = The GDP per capita. Calculated as the Total GDP divided by the total population.

# %%
import pandas as pd
df=pd.read_csv("data_set.csv")
df.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print('No of rows and columns:',df.shape)
print('Categorical columns:',len(df.select_dtypes(exclude=np.number).columns))
print('Numerical columns:',len(df.select_dtypes(include=np.number).columns))
# Out:
# No of rows and columns: (1994, 10)
# Categorical columns: 1
# Numerical columns: 9

# %%
df.describe()
# Out:
#         child_mort      exports       health      imports         income  \
# count  1994.000000  1994.000000  1994.000000  1994.000000    1994.000000
# mean     46.264845    40.897795     6.639102    46.688797   16206.971916
# std      45.875061    23.458995     2.697765    20.897354   17966.906767
# min       2.600000     0.109000     1.810000     0.065900     609.000000
# 25%       7.300000    23.800000     4.860000    30.400000    3060.000000
# 50%      24.100000    39.200000     5.970000    43.600000    7350.000000
# 75%      88.200000    51.300000     8.100000    57.500000   27200.000000
# max     208.000000   200.000000    17.900000   174.000000  125000.000000
#
#          inflation   life_expec    total_fer           gdpp
# count  1994.000000  1994.000000  1994.000000    1994.000000
# mean      7.293361    69.970361     3.165587   13138.625376
# std       9.218182     8.967489     1.722085   18465.680528
# min      -4.210000    32.100000     1.150000     231.000000
# ...

# %%
#there is only one categorical column
df['country'].describe()
# Out:
# count       1994
# unique       167
# top       Bhutan
# freq         128
# Name: country, dtype: object

# %%
cor=df.corr()
sns.heatmap(cor,annot=True,cmap='viridis')
plt.show()

# %%
#visualizing  the dataset
sns.pairplot(df)

# %%
#checking for null values
df.isna().sum()
# Out:
# country       0
# child_mort    0
# exports       0
# health        0
# imports       0
# income        0
# inflation     0
# life_expec    0
# total_fer     0
# gdpp          0
# dtype: int64

# %%
df[df['country']=='Afghanistan']
# Out:
#           country  child_mort  exports  health  imports  income  inflation  \
# 0     Afghanistan        90.2     10.0    7.58     44.9    1610       9.44
# 409   Afghanistan        90.2     10.0    7.58     44.9    1610       9.44
# 488   Afghanistan        90.2     10.0    7.58     44.9    1610       9.44
# 706   Afghanistan        90.2     10.0    7.58     44.9    1610       9.44
# 868   Afghanistan        90.2     10.0    7.58     44.9    1610       9.44
# 1072  Afghanistan        90.2     10.0    7.58     44.9    1610       9.44
# 1318  Afghanistan        90.2     10.0    7.58     44.9    1610       9.44
# 1603  Afghanistan        90.2     10.0    7.58     44.9    1610       9.44
#
#       life_expec  total_fer  gdpp
# 0           56.2       5.82   553
# 409         56.2       5.82   553
# 488         56.2       5.82   553
# 706         56.2       5.82   553
# 868         56.2       5.82   553
# 1072        56.2       5.82   553
# 1318        56.2       5.82   553
# ...

# %%
df[df['country']=='Algeria']
# Out:
#       country  child_mort  exports  health  imports  income  inflation  \
# 2     Algeria        27.3     38.4    4.17     31.4   12900       16.1
# 411   Algeria        27.3     38.4    4.17     31.4   12900       16.1
# 490   Algeria        27.3     38.4    4.17     31.4   12900       16.1
# 708   Algeria        27.3     38.4    4.17     31.4   12900       16.1
# 870   Algeria        27.3     38.4    4.17     31.4   12900       16.1
# 1074  Algeria        27.3     38.4    4.17     31.4   12900       16.1
# 1320  Algeria        27.3     38.4    4.17     31.4   12900       16.1
# 1605  Algeria        27.3     38.4    4.17     31.4   12900       16.1
#
#       life_expec  total_fer  gdpp
# 2           76.5       2.89  4460
# 411         76.5       2.89  4460
# 490         76.5       2.89  4460
# 708         76.5       2.89  4460
# 870         76.5       2.89  4460
# 1074        76.5       2.89  4460
# 1320        76.5       2.89  4460
# 1605        76.5       2.89  4460

# %% [markdown]
# **Each country have repeated records(duplicates) in the dataset.Hence it wouldnt make sense to have the same data multiple times,therefore dropping duplicate columns.**

# %%
df.duplicated().sum()
# Out:
# 1826

# %%
df=df.drop_duplicates()
df.shape
# Out:
# (168, 10)

# %%
df=df.reset_index(drop=True)
df.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
num_col=df.iloc[:,1:].columns
fig,ax=plt.subplots(len(num_col),figsize=(14,9))
for var,sub in zip(num_col,ax.flatten()):
    sns.boxplot(df[var],ax=sub)
plt.tight_layout()
plt.show()

# %% [markdown]
# Except 'total_fer', all the other numeric columns have outliers.

# %%
def outlier_treat(d,cols):
    for i in cols:
        q1=d[i].quantile(0.25)
        q3=d[i].quantile(0.75)
        iqr=q3-q1
        ub=q3+iqr*1.5
        lb=q1-iqr*1.5
        uv=d[i].quantile(0.99)
        lv=d[i].quantile(0.01)
        for j in range(len(d)):
            if d[i][j]>ub:
                d[i][j]=uv
            if d[i][j]<lb:
                d[i][j]=lv

# %%
outs=df.drop(['country','total_fer'],axis=1).columns
outlier_treat(df,outs)
# Out:
# /home/deploy/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /home/deploy/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
num_col=df.iloc[:,1:].columns
fig,ax=plt.subplots(len(num_col),figsize=(14,9))
for var,sub in zip(num_col,ax.flatten()):
    sns.boxplot(df[var],ax=sub)
plt.tight_layout()
plt.show()

# %%
df[df['country']=='Argentina']
# Out:
#      country  child_mort  exports  health  imports  income  inflation  \
# 5  Argentina        14.5     18.9     8.1     16.0   18700       20.9
# 6  Argentina        15.5     18.9     8.1     16.0   18700       20.9
#
#    life_expec  total_fer   gdpp
# 5        75.8       2.37  10300
# 6        75.8       2.37  10300

# %%
df=df.drop_duplicates(subset=['country'])

# %%
df=df.reset_index(drop=True)
df1=df.copy(deep=True)#making a copy of df before building the model
df=df.drop('country',axis=1)

# %%
df.head()
# Out:
#    child_mort  exports  health  imports  income  inflation  life_expec  \
# 0        90.2     10.0    7.58     44.9    1610       9.44        56.2
# 1        16.6     28.0    6.55     48.6    9930       4.49        76.3
# 2        27.3     38.4    4.17     31.4   12900      16.10        76.5
# 3       119.0     62.3    2.85     42.9    5900      22.40        60.1
# 4        10.3     45.5    6.03     58.9   19100       1.44        76.8
#
#    total_fer   gdpp
# 0       5.82    553
# 1       1.65   4090
# 2       2.89   4460
# 3       6.16   3530
# 4       2.13  12200

# %%
df.shape
# Out:
# (167, 9)

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

# %%
df_scaled=pd.DataFrame(ss.fit_transform(df),columns=df.columns)
df_scaled.head()
# Out:
#    child_mort   exports    health   imports    income  inflation  life_expec  \
# 0    1.338433 -1.116961  0.301327 -0.084404 -0.804090   0.220572   -1.691849
# 1   -0.546825 -0.480053 -0.088927  0.069802 -0.382237  -0.366928    0.661850
# 2   -0.272745 -0.112062 -0.990679 -0.647049 -0.231647   1.011026    0.685270
# 3    2.076142  0.733609 -1.490810 -0.167759 -0.586572   1.758753   -1.235161
# 4   -0.708199  0.139162 -0.285949  0.499079  0.082714  -0.728922    0.720400
#
#    total_fer      gdpp
# 0   1.902882 -0.623481
# 1  -0.859973 -0.491101
# 2  -0.038404 -0.477253
# 3   2.128151 -0.512060
# 4  -0.541946 -0.187565

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=0.90)
pc_model=pca.fit_transform(df_scaled)

# %%
pc_model.shape
# Out:
# (167, 5)

# %% [markdown]
# *Five components is enough to explain 90% of the variation in data for this dataset*

# %%
#c)
pcs=pd.DataFrame(pc_model,columns=['pc1','pc2','pc3','pc4','pc5'])
pcs.head()
# Out:
#         pc1       pc2       pc3       pc4       pc5
# 0 -2.944089 -0.019356 -0.789133  1.031903 -0.062642
# 1  0.482843 -0.424254 -0.340254 -1.252913  0.064681
# 2 -0.345832 -0.443088  1.372921 -0.864857  0.270036
# 3 -3.161576  1.406392  1.749460  1.139636 -0.049894
# 4  1.019048  0.266324 -0.251315 -0.908083 -0.317489

# %%
sns.heatmap(pcs.corr())

# %% [markdown]
# No,there is no multicolinearity between the Principal components.

# %%
#checking normality
pc_col=pcs.columns
fig,ax=plt.subplots(len(pc_col),figsize=(14,9))
for var,sub in zip(pc_col,ax.flatten()):
    sns.distplot(pcs[var],ax=sub)
plt.tight_layout()
plt.show()

# %%
#e)
pcs.boxplot()

# %%
outlier_treat(pcs,pcs.drop('pc4',axis=1).columns)

# %%
pcs.boxplot()

# %%
from sklearn.cluster import KMeans,AgglomerativeClustering

# %% [markdown]
# ## Kmeans

# %%
wcss=[]
for i in range(1,11):
    km=KMeans(n_clusters=i)
    km.fit(pcs)
    wcss.append(km.inertia_)
wcss
# Out:
# [1435.8702842179305,
#  977.3385800410867,
#  742.4512660945046,
#  590.3733484156053,
#  501.99827211240694,
#  443.5854848499182,
#  387.7501200306807,
#  347.02950001168875,
#  310.17566821355535,
#  288.0079776246282]

# %%
plt.plot(wcss,marker='o')

# %% [markdown]
# Looking at the plot and the values of wcss the inertia,slowly decreases after 3

# %%
k_means=KMeans(n_clusters=3)
km_model=k_means.fit(pcs)
df['k_label']=km_model.labels_

# %%
sns.pairplot(df,hue='k_label')
plt.show()
# Out:
# /home/deploy/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /home/deploy/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# /home/deploy/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /home/deploy/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# /home/deploy/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
# ...

# %% [markdown]
# ## Agglomerative clustering

# %%
#using silhouette score instead of dendrogram
for i in range(2,8):
    agg=AgglomerativeClustering(n_clusters=i,linkage='complete')
    apred=km.fit_predict(pcs)
    score=silhouette_score(pcs,apred)
    print(i,':',score)
# Out:
# 2 : 0.2540334725106489
# 3 : 0.27168307150787024
# 4 : 0.2704877502001525
# 5 : 0.2695269873307254
# 6 : 0.2748790150297946
# 7 : 0.2663222111996512

# %%
ag=AgglomerativeClustering(n_clusters=4,linkage='ward')
ag.fit(pcs)
df['agg_label']=ag.labels_

# %%
sns.pairplot(df,hue='agg_label')
plt.show()
# Out:
# /home/deploy/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /home/deploy/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# /home/deploy/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /home/deploy/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# /home/deploy/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
# ...

# %%
#evaluating the Kmeans model
from sklearn.metrics import silhouette_score
for i in range(2,8):
    km=KMeans(n_clusters=i)
    pred=km.fit_predict(pcs)
    score=silhouette_score(pcs,pred)
    print(i,':',score)
# Out:
# 2 : 0.2928570080005076
# 3 : 0.3413776261358778
# 4 : 0.3595219728327157
# 5 : 0.3265684817101399
# 6 : 0.29212777540434565
# 7 : 0.30730889694670493

# %%
#evaluating agglomerative model
for i in range(2,8):
    agg=AgglomerativeClustering(n_clusters=i,linkage='complete')
    apred=km.fit_predict(pcs)
    score=silhouette_score(pcs,apred)
    print(i,':',score)
# Out:
# 2 : 0.3003122749784338
# 3 : 0.30730889694670493
# 4 : 0.3040610775212186
# 5 : 0.30983506917550896
# 6 : 0.3127369390334638
# 7 : 0.31538292917352634

# %% [markdown]
# Looking the silhouette scores of both the models,Kmeans has better score than agglomerative clustering.Hence Kmeans with 4 cluster seem to be the better option.

# %%
k_means=KMeans(n_clusters=4)
km_model=k_means.fit(pcs)
df['k4_label']=km_model.labels_

# %%
sns.pairplot(df,hue='k4_label')
# Out:
# /home/deploy/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /home/deploy/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# /home/deploy/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /home/deploy/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# /home/deploy/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
# ...

# %% [markdown]
# the above kmeans model with 4 cluster seeem to overlap in most of the columns,Hence we stick with Kmeans with 3 cluster as our best model.

# %%
df.columns
# Out:
# Index(['child_mort', 'exports', 'health', 'imports', 'income', 'inflation',
#        'life_expec', 'total_fer', 'gdpp', 'k_label', 'agg_label', 'k4_label'],
#       dtype='object')

# %%
df=df.drop(['agg_label','k4_label'],axis=1)
col=df.drop('k_label',axis=1).columns

# %% [markdown]
# ## Findings

# %%
fig,ax=plt.subplots(nrows=3,ncols=3,figsize=(15,12))
for var,sub in zip(col,ax.flatten()):
    sns.barplot(x=df1['k_label'],y=df1[var],ax=sub)
plt.tight_layout()
plt.show()

# %% [markdown]
# Looking at the plot,
# * 'child_mort':The average infant death(for 1000) is very high for label 1 when compared with the other two labels,meaning that more children are dying for countries that belong to label 1.
# * 'Exports': The export for label 2 is higher while label 1 exports the least,label 2 has higher export rate followed by label 0 and label 1.
# * 'Health':The label 2 spends more on health when compared to the other two labels,even for spending in health label 1 is even slightly lower than label 0.
# * 'Imports':Label 0 has least import rate.
# * 'Income':The net income per person is very low for label 1,whereas label 2 has very high net income per persom.label 0 also has lower income per person,which means that people are rich in countries with label 2.
# * 'Inflation':High Inflation means that there are many debts in those countries,label 1 has many debts while label 2 has lowest inflation.
# * 'Life expectancy':Label 2 has higher life expectancy,this may be due the fact that most people in those countires are speding more money on health than the rest of the labels.
# * 'Total_fertility': Again here label 1 seems to dominate with each woman,having a fertility rate of 5 which means that they will tend to have more children,despite earning the least income among the labels.
# * 'GDPP': GDPP for label 2 is the highest which means that,the countries belong to label 2 are rich countries followed by label 0 which may be developing countires and label 1 which looks like poor countries.
#
# **Thus from the above inferences it is clear that the **
# * label 0-are developing countires
# * label 1-are poor countires
# * label 2-are rich countires

# %%
df1[df1['k_label']==1]['country']
# Out:
# 0                   Afghanistan
# 3                        Angola
# 17                        Benin
# 21                     Botswana
# 25                 Burkina Faso
# 26                      Burundi
# 28                     Cameroon
# 31     Central African Republic
# 32                         Chad
# 36                      Comoros
# 37             Congo, Dem. Rep.
# 38                  Congo, Rep.
# 40                Cote d'Ivoire
# 49            Equatorial Guinea
# 50                      Eritrea
# 55                        Gabon
# 56                       Gambia
# 59                        Ghana
# 63                       Guinea
# 64                Guinea-Bissau
# 66                        Haiti
# 72                         Iraq
# 80                        Kenya
# 81                     Kiribati
# 84                          Lao
# 87                      Lesotho
# 88                      Liberia
# 93                   Madagascar
# 94                       Malawi
# ...

# %% [markdown]
# Hence the above countries need to be focused more to for further development.
